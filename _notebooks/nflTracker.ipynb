# %% [markdown]
# ---
# toc: true
# comments: true
# layout: post
# title: NFL CPT
# description: Review of MCQ 12/22
# type: tangibles
# courses: { compsci: {week: 12} }
# ---

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en-US"><head>
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <link rel="stylesheet" href="/student/assets/css/style.css?v=71830ddaa45abf9463f897bc61e1d075c72e8a8d">
#   <script src="https://code.jquery.com/jquery-1.12.4.min.js" integrity="sha256-ZosEbRLbNQzLpnKIkEdrPv7lOy9C27hHQ+Xp8a4MxAQ=" crossorigin="anonymous"></script>
#
#
#   <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no">
#
# </head><body>
#
#   <div class="wrapper">
#     <header><header class="site-header">
#
#   <div id="header">
#     <nav>
#       <ul>
#         <li class="fork"><a href="/student/">Home</a></li>
#         <li class="fork"><a href="/student/compsci">CompSci</a></li>
#         <li class="fork"><a href="/student/blogs">Blogs</a></li>
#         <li class="title"><a href="/student/help">Help</a></li>
#         <li class="title"><a href="https://github.com/saiseahawks/student#readme">View On GitHub</a></li>
#       </ul>
#     </nav>
#   </div><!-- end header -->
# </header></header>
#
#
#     <section>
#       <article class="post h-entry" itemscope itemtype="http://schema.org/BlogPosting">
#
#   <header class="post-header">
#     <h1
#       class="post-title p-name" itemprop="name headline">NFL Simulator
#       • <span class="read-time" title="Estimated read time">
#
#
#       1 min read
#
# </span></h1>
#
#     <p class="post-meta post-meta-title"><time class="dt-published" datetime="" itemprop="datePublished">
#
#       </time>
#     </p></header>
#
#   <div class="post-content e-content" itemprop="articleBody">
#     <html lang="en">
# <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>NFL Game Prediction</title>
# </head>
# <body>
#     <form id="nflForm">
#         <label for="team1">Team 1:</label>
#         <input type="text" id="team1" name="team1" required="" /><br /><br />
#         <label for="team2">Team 2:</label>
#         <input type="text" id="team2" name="team2" required="" /><br /><br />
#         <button type="button" onclick="predictWinner()">Predict Winner</button>
#     </form>
#     <div id="result"></div>
#
#     <script>
#         function predictWinner() {
#             var form = document.getElementById('nflForm');
#             var team1 = document.getElementById('team1').value;
#             var team2 = document.getElementById('team2').value;
#             var resultDiv = document.getElementById('result');
#
#             fetch('http://localhost:8084/api/NFL/predict', {
#                 method: 'POST',
#                 headers: {
#                     'Content-Type': 'application/json',
#                     'Accept': 'application/json'
#                 },
#                 body: JSON.stringify({ "team1": team1, "team2": team2 })
#             })
#             .then(response => response.json())
#             .then(data => {
#                 resultDiv.innerHTML = '<h2>Predicted Likelihood of Winning</h2>';
#                 resultDiv.innerHTML += '<p>' + team1 + ': ' + data[team1] + '%</p>';
#                 resultDiv.innerHTML += '<p>' + team2 + ': ' + data[team2] + '%</p>';
#             })
#             .catch(error => {
#                 console.error('Error:', error);
#             });
#         }
#     </script>
# </body>
# </html>
#
#   </div><a class="u-url" href="/student/NFL" hidden></a>
# </article>
#
#     </section>
#
#   </div>
# </body>
#
#
# </html>

# %%
import sqlite3

# Define a function to create the database table if it doesn't exist
def create_table_if_not_exists():
    conn = sqlite3.connect('nfl_tracker.db')
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS nfl_games
                 (id INTEGER PRIMARY KEY AUTOINCREMENT,
                  home_team TEXT,
                  away_team TEXT,
                  home_team_win_percentage REAL,
                  away_team_win_percentage REAL)''')
    conn.commit()
    conn.close()

# Define the function to add NFL games to the tracker database
def add_game_to_database(home_team, away_team, home_win_percentage, away_win_percentage):
    conn = sqlite3.connect('nfl_tracker.db')
    c = conn.cursor()
    c.execute("INSERT INTO nfl_games (home_team, away_team, home_team_win_percentage, away_team_win_percentage) VALUES (?, ?, ?, ?)",
              (home_team, away_team, home_win_percentage, away_win_percentage))
    conn.commit()
    conn.close()

# Define the function to retrieve all NFL games from the tracker database
def get_all_games_from_database():
    conn = sqlite3.connect('nfl_tracker.db')
    c = conn.cursor()
    c.execute("SELECT home_team, away_team, home_team_win_percentage, away_team_win_percentage FROM nfl_games")
    games = c.fetchall()
    conn.close()
    return games

# Define the function to add NFL games to the tracker
def add_game():
    while True:
        home_team = input("Enter the home team: ")
        away_team = input("Enter the away team: ")
        home_win_percentage = float(input(f"Enter the win percentage for {home_team}: "))
        away_win_percentage = float(input(f"Enter the win percentage for {away_team}: "))

        add_game_to_database(home_team, away_team, home_win_percentage, away_win_percentage)
        print("Game added successfully!")

        another_game = input("Do you want to add another game? (yes/no): ")
        if another_game.lower() != 'yes':
            break

# Main function to run the program
def main():
    # Create the database table if it doesn't exist
    create_table_if_not_exists()

    # Call the add_game function to add games
    add_game()

    # Output the list of tracked NFL games
    print("\nNFL Games Being Tracked:")
    nfl_games = get_all_games_from_database()
    for i, game in enumerate(nfl_games, 1):
        print(f"{i}. Home Team: {game[0]}, Away Team: {game[1]}, Home Win Percentage: {game[2]}, Away Win Percentage: {game[3]}")

# Call the main function to start the program
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 65
#      63 # Call the main function to start the program
#      64 if __name__ == "__main__":
# ---> 65     main()
#
# Cell In[3], line 55, in main()
#      52 create_table_if_not_exists()
#      54 # Call the add_game function to add games
# ---> 55 add_game()
#      57 # Output the list of tracked NFL games
#      58 print("\nNFL Games Being Tracked:")
#
# Cell In[3], line 39, in add_game()
#      37 home_team = input("Enter the home team: ")
#      38 away_team = input("Enter the away team: ")
# ---> 39 home_win_percentage = float(input(f"Enter the win percentage for {home_team}: "))
#      40 away_win_percentage = float(input(f"Enter the win percentage for {away_team}: "))
#      42 add_game_to_database(home_team, away_team, home_win_percentage, away_win_percentage)
#
# ...
